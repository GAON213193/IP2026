# %%
import cv2
import numpy as np

# %%
img = cv2.imread('mountain.jpg')

# %%
px = img[100,100]
print (px)
# Out:
# [205 141  77]

# %%
blue = img[100,100,0]
print (blue)
img[50:100,100:175] = [0,0,255]
print (img[100,100])
# Out:
# 205
# [205 141  77]

# %%
img.item(10,10,2)
img.itemset((10,10,2),100)
img.item(10,10,2)
# Out:
# 100

# %%
print (img.shape)
print (img.size)
print (img.dtype)
# Out:
# (183, 275, 3)
# 150975
# uint8

# %%
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
